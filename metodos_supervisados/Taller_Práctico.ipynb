# %% [markdown]
# <center>
# <img src="https://storage.googleapis.com/adonaivera_certified/banner.png">
#
# ##  Diplomado en Ciencia de Datos - Cohorte 2024
#
# Autor: [Juan Felipe Contreras](https://www.linkedin.com/in/juanf-contreras/)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine

# %%
wine = load_wine(as_frame = True)

# %%
print(wine.DESCR)
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 178
# :Number of Attributes: 13 numeric, predictive attributes and the class
# :Attribute Information:
#     - Alcohol
#     - Malic acid
#     - Ash
#     - Alcalinity of ash
#     - Magnesium
#     - Total phenols
#     - Flavanoids
#     - Nonflavanoid phenols
#     - Proanthocyanins
#     - Color intensity
#     - Hue
#     - OD280/OD315 of diluted wines
#     - Proline
#     - class:
#         - class_0
#         - class_1
#         - class_2
#
# :Summary Statistics:
#
# ============================= ==== ===== ======= =====
#                                 Min   Max   Mean     SD
# ============================= ==== ===== ======= =====
# Alcohol:                      11.0  14.8    13.0   0.8
# Malic Acid:                   0.74  5.80    2.34  1.12
# Ash:                          1.36  3.23    2.36  0.27
# ...

# %%
df = wine.data
df['class'] = wine.target

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
wine.target_names
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %% [markdown]
# **Actividad:**
#
# - Realizar un EDA preliminar de este dataset, identifique la distribución de las columnas y cree una matriz de correlaciones
# - Realice un pairplot entre todas las columnas (use la librería Seaborn)
# - Intente predecir la variable "class" por medio del resto de columnas. Intente con más de un modelo.
