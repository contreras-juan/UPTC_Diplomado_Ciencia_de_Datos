# %% [markdown]
# Nombre de estudiante: Andrés Felipe Flórez Olivera //
#
# Diplomado en Ciencia de Datos //
#
# 2024

# %% [markdown]
# #Ahora un caso aplicado desde cero
#
# Hazlo tú también, paso a paso!

# %% [markdown]
# Estamos aprendiendo Análisis Exploratorio de Datos(Exploratory Data Analysis):EDA //
#
# 1. Identificar el conjunto de datos: train.csv
# 2. Importar y leer el conjunto de datos: Pandas ; pd.read_csv
# 3. Obtener una aproximación de primera vista del conjunto de datos:
# 3.1. Tamaño del conjunto datos (dimension)
# 3.2. Columnas del conjunto de datos (dimensionalidad): # de variables
# 3.3. Identificar los tipos de datos (clases de datos): numerico, flotante, string.
# 3.4. (Opcional): Ver cómo se organiza el dataset: inicio:.head(1), final:.tail(1), aleatorio: .sample(1)
# 4. Aplicación de los dos comodines:
# - Mostrará la información general del dataset:.info(),
# - Mostrará la información estadística de los datos:.describe()
# 5. Ya veremos...

# %%
#Importacion de pandas:
import pandas as pd

# %%
#Carga y lectura de datos:
datos = pd.read_csv("/content/train.csv")

# %%
#Primera vista del conjunto de datos:

#Obtener la dimension:
datos.shape
# Out:
# (891, 12)

# %%
#Obtener la dimensionalidad:
datos.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Identificar los tipos de datos:
datos.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#OPCIONAL:

#Los primeros 5 datos:
datos.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Un dato aleatorio:
datos.sample(1)
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 869          870         1       3  Johnson, Master. Harold Theodor  male
#
#      Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 869  4.0      1      1  347742  11.1333   NaN        S

# %%
#MOSTRAR INFORMACION GENERAL DEL DATASET - Info:

datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
datos.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ###Continuando...
#
# 5. Modificación de los tipos de datos almacenados en una columna (OPCIONAL)

# %%
datos["Fare"] = datos["Fare"].astype("int64")

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    int64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### Continuando...
#  6. Renombrar o transformar columnas:

# %%
datos.rename(columns={"PassengerId":"ID"}, inplace = True)

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        891 non-null    int64
#  1   Survived  891 non-null    int64
#  2   Pclass    891 non-null    int64
#  3   Name      891 non-null    object
#  4   Sex       891 non-null    object
#  5   Age       714 non-null    float64
#  6   SibSp     891 non-null    int64
#  7   Parch     891 non-null    int64
#  8   Ticket    891 non-null    object
#  9   Fare      891 non-null    int64
#  10  Cabin     204 non-null    object
#  11  Embarked  889 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 7. Ordenando el dataset:

# %%
datos.sort_values("Fare")
# Out:
#       ID  Survived  Pclass                                Name     Sex   Age  \
# 822  823         0       1     Reuchlin, Jonkheer. John George    male  38.0
# 179  180         0       3                 Leonard, Mr. Lionel    male  36.0
# 466  467         0       2               Campbell, Mr. William    male   NaN
# 263  264         0       1               Harrison, Mr. William    male  40.0
# 806  807         0       1              Andrews, Mr. Thomas Jr    male  39.0
# ..   ...       ...     ...                                 ...     ...   ...
# 88    89         1       1          Fortune, Miss. Mabel Helen  female  23.0
# 438  439         0       1                   Fortune, Mr. Mark    male  64.0
# 679  680         1       1  Cardeza, Mr. Thomas Drake Martinez    male  36.0
# 737  738         1       1              Lesurer, Mr. Gustave J    male  35.0
# 258  259         1       1                    Ward, Miss. Anna  female  35.0
#
# ...

# %%
datos.sort_values("Age")
# Out:
#       ID  Survived  Pclass                                      Name     Sex  \
# 803  804         1       3           Thomas, Master. Assad Alexander    male
# 755  756         1       2                 Hamalainen, Master. Viljo    male
# 644  645         1       3                    Baclini, Miss. Eugenie  female
# 469  470         1       3             Baclini, Miss. Helene Barbara  female
# 78    79         1       2             Caldwell, Master. Alden Gates    male
# ..   ...       ...     ...                                       ...     ...
# 859  860         0       3                          Razi, Mr. Raihed    male
# 863  864         0       3         Sage, Miss. Dorothy Edith "Dolly"  female
# 868  869         0       3               van Melkebeke, Mr. Philemon    male
# 878  879         0       3                        Laleff, Mr. Kristo    male
# 888  889         0       3  Johnston, Miss. Catherine Helen "Carrie"  female
#
# ...

# %% [markdown]
# 8. Seleccionar y filtrar los datos:

# %%
datos[['Name','Age']].sample(5)
# Out:
#                                                   Name   Age
# 561                                  Sivic, Mr. Husein  40.0
# 62                         Harris, Mr. Henry Birkhardt  45.0
# 38                  Vander Planke, Miss. Augusta Maria  18.0
# 156                   Gilnagh, Miss. Katherine "Katie"  16.0
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  33.0

# %% [markdown]
# 9. Ahora, filtrando por una variable:

# %%
datos[datos["Fare"] > 300]
# Out:
#       ID  Survived  Pclass                                Name     Sex   Age  \
# 258  259         1       1                    Ward, Miss. Anna  female  35.0
# 679  680         1       1  Cardeza, Mr. Thomas Drake Martinez    male  36.0
# 737  738         1       1              Lesurer, Mr. Gustave J    male  35.0
#
#      SibSp  Parch    Ticket  Fare        Cabin Embarked
# 258      0      0  PC 17755   512          NaN        C
# 679      0      1  PC 17755   512  B51 B53 B55        C
# 737      0      0  PC 17755   512         B101        C

# %%
datos[datos["Age"] > 70]
# Out:
#       ID  Survived  Pclass                                  Name   Sex   Age  \
# 96    97         0       1             Goldschmidt, Mr. George B  male  71.0
# 116  117         0       3                  Connors, Mr. Patrick  male  70.5
# 493  494         0       1               Artagaveytia, Mr. Ramon  male  71.0
# 630  631         1       1  Barkworth, Mr. Algernon Henry Wilson  male  80.0
# 851  852         0       3                   Svensson, Mr. Johan  male  74.0
#
#      SibSp  Parch    Ticket  Fare Cabin Embarked
# 96       0      0  PC 17754    34    A5        C
# 116      0      0    370369     7   NaN        Q
# 493      0      0  PC 17609    49   NaN        C
# 630      0      0     27042    30   A23        S
# 851      0      0    347060     7   NaN        S

# %%
#Método alternativo:

datos.query('Age > 70')
# Out:
#       ID  Survived  Pclass                                  Name   Sex   Age  \
# 96    97         0       1             Goldschmidt, Mr. George B  male  71.0
# 116  117         0       3                  Connors, Mr. Patrick  male  70.5
# 493  494         0       1               Artagaveytia, Mr. Ramon  male  71.0
# 630  631         1       1  Barkworth, Mr. Algernon Henry Wilson  male  80.0
# 851  852         0       3                   Svensson, Mr. Johan  male  74.0
#
#      SibSp  Parch    Ticket  Fare Cabin Embarked
# 96       0      0  PC 17754    34    A5        C
# 116      0      0    370369     7   NaN        Q
# 493      0      0  PC 17609    49   NaN        C
# 630      0      0     27042    30   A23        S
# 851      0      0    347060     7   NaN        S

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        891 non-null    int64
#  1   Survived  891 non-null    int64
#  2   Pclass    891 non-null    int64
#  3   Name      891 non-null    object
#  4   Sex       891 non-null    object
#  5   Age       714 non-null    float64
#  6   SibSp     891 non-null    int64
#  7   Parch     891 non-null    int64
#  8   Ticket    891 non-null    object
#  9   Fare      891 non-null    int64
#  10  Cabin     204 non-null    object
#  11  Embarked  889 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 10. Involucrar asignación de variables para obtener métricas:

# %%
boletos_primera_clase = datos.loc[datos['Pclass'] == 1, ['Age','Fare']]

# %%
boletos_primera_clase
# Out:
#       Age  Fare
# 1    38.0    71
# 3    35.0    53
# 6    54.0    51
# 11   58.0    26
# 23   28.0    35
# ..    ...   ...
# 871  47.0    52
# 872  33.0     5
# 879  56.0    83
# 887  19.0    30
# 889  26.0    30
#
# [216 rows x 2 columns]

# %%
tarifas_altas = datos.loc[datos['Fare'] > 31, ['Age','Sex']]

# %%
tarifas_altas
# Out:
#       Age     Sex
# 1    38.0  female
# 3    35.0  female
# 6    54.0    male
# 23   28.0    male
# 27   19.0    male
# ..    ...     ...
# 856  45.0  female
# 863   NaN  female
# 867  31.0    male
# 871  47.0  female
# 879  56.0  female
#
# [211 rows x 2 columns]

# %%
datos.iloc[871,4]
# Out:
# 'female'

# %% [markdown]
# 11. IMPORTANTISIMO: Identificar valores duplicados

# %%
datos.duplicated().sum(axis = 0)
# Out:
# 0

# %% [markdown]
# 12. IMPORTANTISIMO: Identificación de valores faltantes

# %%
datos.isnull().sum(axis = 0)
# Out:
# ID            0
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        891 non-null    int64
#  1   Survived  891 non-null    int64
#  2   Pclass    891 non-null    int64
#  3   Name      891 non-null    object
#  4   Sex       891 non-null    object
#  5   Age       714 non-null    float64
#  6   SibSp     891 non-null    int64
#  7   Parch     891 non-null    int64
#  8   Ticket    891 non-null    object
#  9   Fare      891 non-null    int64
#  10  Cabin     204 non-null    object
#  11  Embarked  889 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 13. IMPORTANTISIMO: (PERO OPCIONAL)

# %%
#Podemos rellenar mediante medidas de tendencia central:

#Media
#Mediana
#Moda

edad_imp = round(datos['Age'].mean())

# %%
edad_imp
# Out:
# 30

# %% [markdown]
# #Introducir el valor de imputacion en el dataset:

# %%
datos['Age'].fillna(edad_imp, inplace=True)

# %%
datos.describe()
# Out:
#                ID    Survived      Pclass         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean   446.000000    0.383838    2.308642   29.758889    0.523008    0.381594
# std    257.353842    0.486592    0.836071   13.002570    1.102743    0.806057
# min      1.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    223.500000    0.000000    2.000000   22.000000    0.000000    0.000000
# 50%    446.000000    0.000000    3.000000   30.000000    0.000000    0.000000
# 75%    668.500000    1.000000    3.000000   35.000000    1.000000    0.000000
# max    891.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare
# count  891.000000
# mean    31.785634
# std     49.703730
# min      0.000000
# 25%      7.000000
# 50%     14.000000
# 75%     31.000000
# max    512.000000

# %%
datos.isnull().sum(axis = 0)
# Out:
# ID            0
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# 14. Crear una nueva columna:

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        891 non-null    int64
#  1   Survived  891 non-null    int64
#  2   Pclass    891 non-null    int64
#  3   Name      891 non-null    object
#  4   Sex       891 non-null    object
#  5   Age       891 non-null    float64
#  6   SibSp     891 non-null    int64
#  7   Parch     891 non-null    int64
#  8   Ticket    891 non-null    object
#  9   Fare      891 non-null    int64
#  10  Cabin     204 non-null    object
#  11  Embarked  889 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 83.7+ KB

# %%
#Suponiendo que la oficina vendedora de tickets cobran un impuesto del 30%:
#Debe existir una columna que calcule el costo total del ticket con el impuesto incluido

datos['Valor_Total_Ticket'] = datos["Fare"] * 0.3 + datos["Fare"]

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  891 non-null    int64
#  1   Survived            891 non-null    int64
#  2   Pclass              891 non-null    int64
#  3   Name                891 non-null    object
#  4   Sex                 891 non-null    object
#  5   Age                 891 non-null    float64
#  6   SibSp               891 non-null    int64
#  7   Parch               891 non-null    int64
#  8   Ticket              891 non-null    object
#  9   Fare                891 non-null    int64
#  10  Cabin               204 non-null    object
#  11  Embarked            889 non-null    object
#  12  Valor_Total_Ticket  891 non-null    float64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
datos.head()
# Out:
#    ID  Survived  Pclass                                               Name  \
# 0   1         0       3                            Braund, Mr. Owen Harris
# 1   2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   3         1       3                             Heikkinen, Miss. Laina
# 3   4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   5         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket  Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171     7   NaN        S
# 1  female  38.0      1      0          PC 17599    71   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282     7   NaN        S
# 3  female  35.0      1      0            113803    53  C123        S
# 4    male  35.0      0      0            373450     8   NaN        S
#
#    Valor_Total_Ticket
# 0                 9.1
# 1                92.3
# 2                 9.1
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  891 non-null    int64
#  1   Survived            891 non-null    int64
#  2   Pclass              891 non-null    int64
#  3   Name                891 non-null    object
#  4   Sex                 891 non-null    object
#  5   Age                 891 non-null    float64
#  6   SibSp               891 non-null    int64
#  7   Parch               891 non-null    int64
#  8   Ticket              891 non-null    object
#  9   Fare                891 non-null    int64
#  10  Cabin               204 non-null    object
#  11  Embarked            889 non-null    object
#  12  Valor_Total_Ticket  891 non-null    float64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
#Identificando valores únicos en las variables:

datos["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
datos["Pclass"].unique()
# Out:
# array([3, 1, 2])

# %% [markdown]
# #AHORA SI!
# Viene realizar cálculos, obtener métricas y agrupar!

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  891 non-null    int64
#  1   Survived            891 non-null    int64
#  2   Pclass              891 non-null    int64
#  3   Name                891 non-null    object
#  4   Sex                 891 non-null    object
#  5   Age                 891 non-null    float64
#  6   SibSp               891 non-null    int64
#  7   Parch               891 non-null    int64
#  8   Ticket              891 non-null    object
#  9   Fare                891 non-null    int64
#  10  Cabin               204 non-null    object
#  11  Embarked            889 non-null    object
#  12  Valor_Total_Ticket  891 non-null    float64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
#Miremos los promedios:

promedio_por_edad = datos[['Pclass','Age']].groupby('Pclass').mean()

# %%
edad_round = round(promedio_por_edad)
edad_round
# Out:
#          Age
# Pclass
# 1       37.0
# 2       30.0
# 3       26.0

# %%
#¿Cuántas personas (pasajeros) viajaron en cada una de las clases?

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  891 non-null    int64
#  1   Survived            891 non-null    int64
#  2   Pclass              891 non-null    int64
#  3   Name                891 non-null    object
#  4   Sex                 891 non-null    object
#  5   Age                 891 non-null    float64
#  6   SibSp               891 non-null    int64
#  7   Parch               891 non-null    int64
#  8   Ticket              891 non-null    object
#  9   Fare                891 non-null    int64
#  10  Cabin               204 non-null    object
#  11  Embarked            889 non-null    object
#  12  Valor_Total_Ticket  891 non-null    float64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
datos[['Pclass','ID']].groupby('Pclass').count()
# Out:
#          ID
# Pclass
# 1       216
# 2       184
# 3       491

# %%
datos.describe()
# Out:
#                ID    Survived      Pclass         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean   446.000000    0.383838    2.308642   29.758889    0.523008    0.381594
# std    257.353842    0.486592    0.836071   13.002570    1.102743    0.806057
# min      1.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    223.500000    0.000000    2.000000   22.000000    0.000000    0.000000
# 50%    446.000000    0.000000    3.000000   30.000000    0.000000    0.000000
# 75%    668.500000    1.000000    3.000000   35.000000    1.000000    0.000000
# max    891.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare  Valor_Total_Ticket
# count  891.000000          891.000000
# mean    31.785634           41.321324
# std     49.703730           64.614848
# min      0.000000            0.000000
# 25%      7.000000            9.100000
# ...

# %%
#Cuantas personas eran mujeres:

(datos['Sex'] == 'female').sum()
# Out:
# 314

# %%
datos.query('Sex == "female"').count()
# Out:
# ID                    314
# Survived              314
# Pclass                314
# Name                  314
# Sex                   314
# Age                   314
# SibSp                 314
# Parch                 314
# Ticket                314
# Fare                  314
# Cabin                  97
# Embarked              312
# Valor_Total_Ticket    314
# dtype: int64

# %%
datos.query('Sex == "male"').count()
# Out:
# ID                    577
# Survived              577
# Pclass                577
# Name                  577
# Sex                   577
# Age                   577
# SibSp                 577
# Parch                 577
# Ticket                577
# Fare                  577
# Cabin                 107
# Embarked              577
# Valor_Total_Ticket    577
# dtype: int64

# %%
datos.query('Sex == "female"')['ID'].count()
# Out:
# 314

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  891 non-null    int64
#  1   Survived            891 non-null    int64
#  2   Pclass              891 non-null    int64
#  3   Name                891 non-null    object
#  4   Sex                 891 non-null    object
#  5   Age                 891 non-null    float64
#  6   SibSp               891 non-null    int64
#  7   Parch               891 non-null    int64
#  8   Ticket              891 non-null    object
#  9   Fare                891 non-null    int64
#  10  Cabin               204 non-null    object
#  11  Embarked            889 non-null    object
#  12  Valor_Total_Ticket  891 non-null    float64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
(datos['Survived'] == 0).sum()
# Out:
# 549

# %%
(datos['Survived'] == 1).sum()
# Out:
# 342

# %% [markdown]
# #Procedemos a trabajar con estadísticos básicos

# %%
#Ya conocemos la piedra angular #2!

datos.describe()
# Out:
#                ID    Survived      Pclass         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean   446.000000    0.383838    2.308642   29.758889    0.523008    0.381594
# std    257.353842    0.486592    0.836071   13.002570    1.102743    0.806057
# min      1.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    223.500000    0.000000    2.000000   22.000000    0.000000    0.000000
# 50%    446.000000    0.000000    3.000000   30.000000    0.000000    0.000000
# 75%    668.500000    1.000000    3.000000   35.000000    1.000000    0.000000
# max    891.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare  Valor_Total_Ticket
# count  891.000000          891.000000
# mean    31.785634           41.321324
# std     49.703730           64.614848
# min      0.000000            0.000000
# 25%      7.000000            9.100000
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  891 non-null    int64
#  1   Survived            891 non-null    int64
#  2   Pclass              891 non-null    int64
#  3   Name                891 non-null    object
#  4   Sex                 891 non-null    object
#  5   Age                 891 non-null    float64
#  6   SibSp               891 non-null    int64
#  7   Parch               891 non-null    int64
#  8   Ticket              891 non-null    object
#  9   Fare                891 non-null    int64
#  10  Cabin               204 non-null    object
#  11  Embarked            889 non-null    object
#  12  Valor_Total_Ticket  891 non-null    float64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
data_modified = datos[['Survived','Pclass','Age','Fare']]

# %%
data_modified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Age       891 non-null    float64
#  3   Fare      891 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 28.0 KB

# %%
data_modified.describe()
# Out:
#          Survived      Pclass         Age        Fare
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.758889   31.785634
# std      0.486592    0.836071   13.002570   49.703730
# min      0.000000    1.000000    0.420000    0.000000
# 25%      0.000000    2.000000   22.000000    7.000000
# 50%      0.000000    3.000000   30.000000   14.000000
# 75%      1.000000    3.000000   35.000000   31.000000
# max      1.000000    3.000000   80.000000  512.000000

# %%
#Generar tabla de coeficientes de correlación
#Correlación de Pearson
data_modified.corr()
# Out:
#           Survived    Pclass       Age      Fare
# Survived  1.000000 -0.338481 -0.070657  0.257482
# Pclass   -0.338481  1.000000 -0.329727 -0.550553
# Age      -0.070657 -0.329727  1.000000  0.090834
# Fare      0.257482 -0.550553  0.090834  1.000000
